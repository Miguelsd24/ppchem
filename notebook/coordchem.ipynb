# %%
import sys
import os
from IPython.display import display, Markdown

# Add the 'src' directory to the path
sys.path.append(os.path.abspath("../src"))

import coordchem as cc
from coordchem import show_analysis
formula = "[Co2(m-OH)(m-NH2)(NH3)10]1"
ligand = "m-edta"

#print(cc.parse_metal(formula))
#print(cc.parse_ligands(formula))
#print(cc.ligands_list(formula))
#print(cc.complexe_charge(formula))
#print(cc.parse_elements(formula))
#print(cc.ligands_charge(formula))
#print(cc.oxidation_state(formula))
#print(cc.metal_charge(formula))
#print(cc.count_bridging_ligands(formula))
#print(cc.bond_order(formula))
#print(cc.name_or_abbr_ligands(ligand))
#print(cc.naming_compound(formula))
#print(cc.is_an_abbr(ligand))
show_analysis(formula)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 26
#      11 ligand = "m-edta"
#      13 #print(cc.parse_metal(formula))
#      14 #print(cc.parse_ligands(formula))
#      15 #print(cc.ligands_list(formula))
#    (...)
#      24 #print(cc.naming_compound(formula))
#      25 #print(cc.is_an_abbr(ligand))
# ---> 26 show_analysis(formula)
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:511, in show_analysis(formula)
#     510 def show_analysis(formula):
# --> 511     return display(Markdown(analyze_complexe(formula)[1]))
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:476, in analyze_complexe(formula)
#     475 def analyze_complexe(formula):
# --> 476     parse_elements(formula)
#     477     lines = []
#     479     #Formula
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:223, in parse_elements(formula)
#     221 def parse_elements(formula):
#     222     elements = []
# --> 223     elements.extend(ligands_list(formula))
#     224     elements.extend(parse_metal(formula))
#     225     # We also verify that there is no bridging ligand if there is only one metal center
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:140, in ligands_list(formula)
#     138 def ligands_list(formula):
#     139     ligands_list = []
# --> 140     ligands = parse_ligands(formula)[0]
#     141     coeff = parse_ligands(formula)[1]
#     142     for n in range(len(ligands)):
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:126, in parse_ligands(formula)
#     124 for ligand, n in match:
#     125     if test_string_for_int(n) > 10:
# --> 126         raise ValueError(f"Error: No ligand can have a coefficient superior to 10")
#     127     elif ligand == "":
#     128         raise ValueError(f"Error: At least one ligand is missing in the formula")
#
# ValueError: Error: No ligand can have a coefficient superior to 10

# %%
import py3Dmol
import os

# =========================
# LOAD SDF
# =========================
path = os.path.join("../src", "complex.sdf")

with open(path) as f:
    data = f.read()

# =========================
# VIEW
# =========================
view = py3Dmol.view(width=700, height=550)
view.addModel(data, "sdf")

# =========================
# STICKS (BONDS)
# =========================
view.setStyle({}, {
    "stick": {
        "radius": 0.22,
        "color": "gray",
        "opacity": 0.9
    }
})

# =========================
# ATOMS (SPHERES REDUCED SIZE)
# =========================
view.addStyle({"elem": "Fe"}, {
    "sphere": {
        "scale": 0.75,
        "color": "red"
    }
})

view.addStyle({"elem": "N"}, {
    "sphere": {
        "scale": 0.35,
        "color": "blue"
    }
})

view.addStyle({"elem": "H"}, {
    "sphere": {
        "scale": 0.22,
        "color": "white"
    }
})

# =========================
# CAMERA
# =========================
view.zoomTo()
view.show()
