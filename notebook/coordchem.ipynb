# %%
import sys
import os

# Add the 'src' directory to the path
sys.path.append(os.path.abspath("../src"))

from coordchem import extract_metal
extract_metal("[Fe02()]")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 8
#       5 sys.path.append(os.path.abspath("../src"))
#       7 from coordchem import extract_metal
# ----> 8 extract_metal("[Fe8()]")
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:45, in extract_metal(formula)
#      43     coeff = 1
#      44 elif int(num) > 2:
# ---> 45     raise ValueError("Invalid coefficient, the coordination compound has more than two metal centers.")
#      46 else:
#      47     coeff = int(num)
#
# ValueError: Invalid coefficient, the coordination compound has more than two metal centers.
