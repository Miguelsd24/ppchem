# %%
import sys
import os

# Add the 'src' directory to the path
sys.path.append(os.path.abspath("../src"))

import coordchem as cc
from coordchem import show_analysis
formula = "[Mn(H2O)(en)2(CO)3]"
ligand = "m-edta"

#print(cc.parse_metal(formula))
#print(cc.parse_ligands(formula))
#print(cc.ligands_list(formula))
#print(cc.complexe_charge(formula))
#print(cc.parse_elements(formula))
#print(cc.ligands_charge(formula))
#print(cc.oxidation_state(formula))
#print(cc.metal_charge(formula))
#print(cc.count_bridging_ligands(formula))
#print(cc.bond_order(formula))
#print(cc.name_or_abbr_ligands(ligand))
#print(cc.naming_compound(formula))
#print(cc.is_an_abbr(ligand))
show_analysis(formula)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5 # Add the 'src' directory to the path
#       6 sys.path.append(os.path.abspath("../src"))
# ----> 8 import coordchem as cc
#       9 from coordchem import show_analysis
#      10 formula = "[Mn(H2O)(en)2(CO)3]"
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:63
#      57     return True
#      60 ##################################################################### TO DO <
# ---> 63 print(formula_input_verification("[]"))
#      66 # Function which process the formula to have a better looking LaTeX formula
#      67 def clean_formula(formula):
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:49, in formula_input_verification(formula)
#      47 clean_formula = formula.replace(" ", "")
#      48 if clean_formula == "" or clean_formula == "[]" or clean_formula == "[()]":
# ---> 49     raise ValueError("Error: Formula cannot be empty")
#      50 clean_formula = formula.replace(" ", "")
#      51 print(clean_formula)
#
# ValueError: Error: Formula cannot be empty

# %%
import nglview as nv
formula = "[Mn(H2O)(CO)2(NH3)3]"
compound = cc.create_compound_render(formula)
view = nv.show_ase(compound)
# Clear everything currently being shown
view.clear_representations()

# Add a specific representation
view.add_ball_and_stick(radius=0.1)  # Good for seeing bonds
view.add_spacefill(radius=0.8)       # Good for seeing steric bulk/surface
view.add_licorice()        
          # Thick sticks, classic "chem" look
view
# Out:
# NGLWidget()
