# %%
import sys
import os

# Add the 'src' directory to the path
sys.path.append(os.path.abspath("../src"))

import coordchem as cc
from coordchem import show_analysis
formula = "[Co2(m-Co)2(NH3)10]"
ligand = "m-edta"

#print(cc.parse_metal(formula))
#print(cc.parse_ligands(formula))
#print(cc.ligands_list(formula))
#print(cc.complexe_charge(formula))
#print(cc.parse_elements(formula))
#print(cc.ligands_charge(formula))
#print(cc.oxidation_state(formula))
#print(cc.metal_charge(formula))
#print(cc.count_bridging_ligands(formula))
#print(cc.bond_order(formula))
#print(cc.name_or_abbr_ligands(ligand))
#print(cc.naming_compound(formula))
#print(cc.is_an_abbr(ligand))

show_analysis(formula)
# Out:
# IUPAC Name : Tetrahydroxoferrate(III)
#
# Metal : Fe (3+)
#
# Electronic structure : [Ar] 4s0 3d5
#
# Electron count : 13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 26
#      10 ligand = "m-edta"
#      12 #print(cc.parse_metal(formula))
#      13 #print(cc.parse_ligands(formula))
#      14 #print(cc.ligands_list(formula))
#    (...)
#      23 #print(cc.naming_compound(formula))
#      24 #print(cc.is_an_abbr(ligand))
# ---> 26 show_analysis(formula)
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:416, in show_analysis(formula)
#     415 def show_analysis(formula):
# --> 416     return analyze_complexe(formula)
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:391, in analyze_complexe(formula)
#     388 lines = []
#     390 # Nomenclature
# --> 391 name = naming_compound(formula)
#     392 lines.append(f"IUPAC Name : {name}")
#     394 # Metal charge part
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:323, in naming_compound(formula)
#     321 def naming_compound(formula):
#     322     # 1. We set the data nedded
# --> 323     parsed_data = parse_ligands(formula)
#     324     ligands = parsed_data[0]
#     325     coeffs = parsed_data[1]
#
# File c:\Users\migus\git\ppchem\src\coordchem.py:110, in parse_ligands(formula)
#     108     raise ValueError(f"Error: At least one ligand is missing in the formula")
#     109 if find_ligand(ligand) == False:
# --> 110     raise ValueError(f"Error: Ligand {ligand} not in the database")
#     111 else:
#     112     coeff.append(test_string_for_int(n))
#
# ValueError: Error: Ligand m-Co not in the database

# %%
import py3Dmol
import os

# =========================
# LOAD SDF
# =========================
path = os.path.join("../src", "complex.sdf")

with open(path) as f:
    data = f.read()

# =========================
# VIEW
# =========================
view = py3Dmol.view(width=700, height=550)
view.addModel(data, "sdf")

# =========================
# STICKS (BONDS)
# =========================
view.setStyle({}, {
    "stick": {
        "radius": 0.22,
        "color": "gray",
        "opacity": 0.9
    }
})

# =========================
# ATOMS (SPHERES REDUCED SIZE)
# =========================
view.addStyle({"elem": "Fe"}, {
    "sphere": {
        "scale": 0.75,
        "color": "red"
    }
})

view.addStyle({"elem": "N"}, {
    "sphere": {
        "scale": 0.35,
        "color": "blue"
    }
})

view.addStyle({"elem": "H"}, {
    "sphere": {
        "scale": 0.22,
        "color": "white"
    }
})

# =========================
# CAMERA
# =========================
view.zoomTo()
view.show()
